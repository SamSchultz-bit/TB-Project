# %% [markdown]
# # Question 2: How does HIV affect TB Infection and Mortality

# %%
import warnings
warnings.filterwarnings('ignore')
from pathlib import Path
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
# Import CSV
TB_Rates = Path('Resources/TB_Rates_Cleaned.csv')
HDI = Path('Resources/HDI.csv')

# Create Data Frame
tb_rates_df = pd.read_csv(TB_Rates)
hdi_df = pd.read_csv(HDI)

# %%
# Drop Columns
tb_drop =   ['iso2',
            'iso3','iso_numeric',
            'g_whoregion',
            'e_inc_100k_lo',
            'e_inc_100k_hi',
            'cfr_lo',
            'cfr_hi',
            'cfr_pct_lo',
            'cfr_pct_hi',
            'c_cdr',
            'c_cdr_lo',
            'c_cdr_hi',
            'e_inc_num_lo',
            'e_inc_num_hi',
            'e_tbhiv_prct_lo',
            'e_tbhiv_prct_hi',
            'e_inc_tbhiv_100k_lo',
            'e_inc_tbhiv_100k_hi',
            'e_inc_tbhiv_num_lo',
            'e_inc_tbhiv_num_hi',
            'e_mort_exc_tbhiv_100k_lo',
            'e_mort_exc_tbhiv_100k_hi',
            'e_mort_tbhiv_100k_lo',
            'e_mort_tbhiv_100k_hi',
            'e_mort_tbhiv_num_lo',
            'e_mort_tbhiv_num_hi',
            'e_mort_100k_lo',
            'e_mort_100k_hi',
            'e_mort_num_lo',
            'e_mort_num_hi',
            'e_mort_exc_tbhiv_num_lo',
            'e_mort_exc_tbhiv_num_hi',
            ]
tb_rates_df.drop(tb_drop, inplace=True, axis=1)
tb_rates_df.columns
# Out:
# Index(['country', 'year', 'e_pop_num', 'e_inc_100k', 'e_inc_num',
#        'e_tbhiv_prct', 'e_inc_tbhiv_100k', 'e_inc_tbhiv_num',
#        'e_mort_exc_tbhiv_100k', 'e_mort_exc_tbhiv_num', 'e_mort_tbhiv_100k',
#        'e_mort_tbhiv_num', 'e_mort_100k', 'e_mort_num', 'cfr', 'cfr_pct',
#        'c_newinc_100k'],
#       dtype='object')

# %%
#Rename Remaining columns
tb_rename = {'country':'Country', 
            'year':'Year', 
            'e_pop_num':'Population', 
            'e_inc_100k': 'Cases per Cap.(All)', 
            'e_inc_num': 'Cases',
            'e_tbhiv_prct': 'Cases - HIV & TB %', 
            'e_inc_tbhiv_100k': 'Cases -HIV & TB per Cap.', 
            'e_inc_tbhiv_num': 'Cases - HIV & TB',
            'e_mort_exc_tbhiv_100k': 'Mortality - TB (exclude HIV)per Cap', 
            'e_mort_exc_tbhiv_num': 'Mortality - TB (exclude HIV)', 
            'e_mort_tbhiv_100k': 'Mortality - HIV & TB incident per Cap.',
            'e_mort_tbhiv_num':'Mortality - HIV & TB', 
            'e_mort_100k':'Mortality - Per Cap', 
            'e_mort_num': 'Mortality', 
            'cfr':'Case Fatality Ratio', 
            'cfr_pct': 'Case Fatality Ratio %',
            'c_newinc_100k': 'Total New and Relapse Cases'}
tb_rates_df.rename(columns=tb_rename, inplace=True)
hdi_df.rename(columns={'Country_Name':'Country'}, inplace=True)

# %%
tb_rates_df
# Out:
#           Country  Year  Population  Cases per Cap.(All)  Cases  \
# 0     Afghanistan  2000    19542982                190.0  37000
# 1     Afghanistan  2001    19688632                189.0  37000
# 2     Afghanistan  2002    21000256                189.0  40000
# 3     Afghanistan  2003    22645130                189.0  43000
# 4     Afghanistan  2004    23553551                189.0  44000
# ...           ...   ...         ...                  ...    ...
# 4697     Zimbabwe  2017    14751101                221.0  33000
# 4698     Zimbabwe  2018    15052184                210.0  32000
# 4699     Zimbabwe  2019    15354608                199.0  31000
# 4700     Zimbabwe  2020    15669666                181.0  28000
# 4701     Zimbabwe  2021    15993524                190.0  30000
#
#       Cases - HIV & TB %  Cases -HIV & TB per Cap.  Cases - HIV & TB  \
# 0                   0.02                      0.03               6.0
# 1                   0.01                      0.03               6.0
# 2                   0.01                      0.03               6.0
# 3                   0.01                      0.03               6.0
# 4                   0.01                      0.03               6.0
# ...                  ...                       ...               ...
# 4697               63.00                    140.00           21000.0
# 4698               62.00                    130.00           20000.0
# 4699               60.00                    119.00           18000.0
# 4700               61.00                    108.00           17000.0
# 4701               62.00                    116.00           18000.0
#
#       Mortality - TB (exclude HIV)per Cap  Mortality - TB (exclude HIV)  \
# 0                                    68.0                       13000.0
# 1                                    63.0                       12000.0
# 2                                    57.0                       12000.0
# 3                                    58.0                       13000.0
# 4                                    51.0                       12000.0
# ...                                   ...                           ...
# 4697                                  8.3                        1200.0
# 4698                                  7.7                        1200.0
# 4699                                 11.0                        1700.0
# 4700                                 12.0                        1800.0
# 4701                                 13.0                        2000.0
#
#       Mortality - HIV & TB incident per Cap.  Mortality - HIV & TB  \
# 0                                       0.17                  33.0
# 1                                       0.30                  60.0
# 2                                       0.27                  57.0
# 3                                       0.29                  66.0
# 4                                       0.29                  67.0
# ...                                      ...                   ...
# 4697                                   27.00                4000.0
# 4698                                   24.00                3600.0
# 4699                                   31.00                4800.0
# 4700                                   30.00                4700.0
# 4701                                   33.00                5300.0
#
#       Mortality - Per Cap  Mortality  Case Fatality Ratio  \
# 0                    68.0    13000.0                  NaN
# 1                    63.0    12000.0                  NaN
# 2                    57.0    12000.0                  NaN
# 3                    58.0    13000.0                  NaN
# 4                    52.0    12000.0                  NaN
# ...                   ...        ...                  ...
# 4697                 35.0     5200.0                  NaN
# 4698                 32.0     4800.0                  NaN
# 4699                 43.0     6600.0                  NaN
# 4700                 42.0     6600.0                  NaN
# 4701                 46.0     7300.0                 0.25
#
#       Case Fatality Ratio %  Total New and Relapse Cases
# 0                       NaN                         36.0
# 1                       NaN                         51.0
# 2                       NaN                         66.0
# 3                       NaN                         61.0
# 4                       NaN                         78.0
# ...                     ...                          ...
# 4697                    NaN                        175.0
# 4698                    NaN                        167.0
# 4699                    NaN                        137.0
# 4700                    NaN                        100.0
# 4701                   25.0                        102.0
#
# [4702 rows x 17 columns]

# %%
# handle nas
tb_rates_df["Case Fatality Ratio"].fillna(0, inplace = True)
tb_rates_df["Case Fatality Ratio %"].fillna(0, inplace = True)
tb_rates_df.head()
# Out:
#        Country  Year  Population  Cases per Cap.(All)  Cases  \
# 0  Afghanistan  2000    19542982                190.0  37000
# 1  Afghanistan  2001    19688632                189.0  37000
# 2  Afghanistan  2002    21000256                189.0  40000
# 3  Afghanistan  2003    22645130                189.0  43000
# 4  Afghanistan  2004    23553551                189.0  44000
#
#    Cases - HIV & TB %  Cases -HIV & TB per Cap.  Cases - HIV & TB  \
# 0                0.02                      0.03               6.0
# 1                0.01                      0.03               6.0
# 2                0.01                      0.03               6.0
# 3                0.01                      0.03               6.0
# 4                0.01                      0.03               6.0
#
#    Mortality - TB (exclude HIV)per Cap  Mortality - TB (exclude HIV)  \
# 0                                 68.0                       13000.0
# 1                                 63.0                       12000.0
# 2                                 57.0                       12000.0
# 3                                 58.0                       13000.0
# 4                                 51.0                       12000.0
#
#    Mortality - HIV & TB incident per Cap.  Mortality - HIV & TB  \
# 0                                    0.17                  33.0
# 1                                    0.30                  60.0
# 2                                    0.27                  57.0
# 3                                    0.29                  66.0
# 4                                    0.29                  67.0
#
#    Mortality - Per Cap  Mortality  Case Fatality Ratio  Case Fatality Ratio %  \
# 0                 68.0    13000.0                  0.0                    0.0
# 1                 63.0    12000.0                  0.0                    0.0
# 2                 57.0    12000.0                  0.0                    0.0
# 3                 58.0    13000.0                  0.0                    0.0
# 4                 52.0    12000.0                  0.0                    0.0
#
#    Total New and Relapse Cases
# 0                         36.0
# 1                         51.0
# 2                         66.0
# 3                         61.0
# 4                         78.0

# %%
#Merge dataframes
merged_df = pd.merge(tb_rates_df, hdi_df, how='inner', on='Country')

#Find HDI quartiles
merged_df.quantile([0.25,0.75])

#Created DF for countries with low HDI
low_hdi_df = merged_df.loc[merged_df['Human Development Index (HDI) (Value)'] < 0.60050].reset_index(drop=True)

#Create DF for Countries with high HDi
high_hdi_df = merged_df.loc[merged_df['Human Development Index (HDI) (Value)'] > 0.82375].reset_index(drop=True)

# %%
#Group DF by year
by_year_df = tb_rates_df.groupby(by="Year").mean()
by_year_df.reset_index()

low_by_year_df = low_hdi_df.groupby(by="Year").mean()
low_by_year_df.reset_index()

high_by_year_df = high_hdi_df.groupby(by="Year").mean()
high_by_year_df.reset_index()

#reset index
by_year_df = by_year_df.reset_index()
by_year_df

low_by_year_df = low_by_year_df.reset_index()
by_year_df

high_by_year_df = high_by_year_df.reset_index()
by_year_df

by_year_df['Mortality Rate'] = (by_year_df['Mortality - TB (exclude HIV)'] / by_year_df['Cases'])
by_year_df['Mortality Rate - HIV'] = (by_year_df['Mortality - HIV & TB'] / by_year_df['Cases - HIV & TB'])
by_year_df
# Out:
#     Year    Population  Cases per Cap.(All)         Cases  Cases - HIV & TB %  \
# 0   2000  2.901080e+07           139.450711  53252.180095           17.752470
# 1   2001  2.939774e+07           139.953791  53990.374408           16.278675
# 2   2002  2.964764e+07           142.831132  54445.023585           15.100359
# 3   2003  3.003133e+07           144.697689  55134.910377           13.985930
# 4   2004  3.041683e+07           143.645991  55486.589623           13.673931
# 5   2005  3.066049e+07           142.609014  55484.943662           13.461955
# 6   2006  3.105080e+07           141.048028  55493.600939           13.526011
# 7   2007  3.144717e+07           138.315962  55300.483568           12.765055
# 8   2008  3.184885e+07           135.736620  55073.502347           13.112350
# 9   2009  3.225557e+07           134.135869  54917.544601           13.325895
# 10  2010  3.251236e+07           131.517150  54098.261682           12.685937
# 11  2011  3.276776e+07           127.074372  53529.613953           12.433782
# 12  2012  3.317909e+07           122.968651  53162.920930           12.690538
# 13  2013  3.359198e+07           119.456930  52549.018605           12.013102
# 14  2014  3.400277e+07           114.525953  52066.060465           11.939412
# 15  2015  3.440964e+07           112.163209  51504.660465           10.984785
# 16  2016  3.481322e+07           108.661860  50626.753488           10.902435
# 17  2017  3.521443e+07           104.609814  49624.060465            9.695765
# 18  2018  3.560461e+07           104.022140  48918.325581            9.615625
# 19  2019  3.598179e+07            99.940605  48114.200000            9.487083
# 20  2020  3.633498e+07            96.535209  47012.934884            9.102564
# 21  2021  3.665254e+07            97.057860  49121.158140            8.649797
#
#     Cases -HIV & TB per Cap.  Cases - HIV & TB  \
# 0                  57.928855      10753.216867
# 1                  55.710361      10082.987952
# 2                  53.716467       9570.880240
# 3                  52.185291       9162.709302
# 4                  51.147399       9051.306358
# 5                  50.233352       8992.698324
# 6                  50.016940       9068.311475
# 7                  47.170824       8703.604396
# 8                  45.395464       8754.852459
# 9                  43.895895       8393.100000
# 10                 41.516042       7940.812500
# 11                 37.623523       7647.077720
# 12                 35.461129       7593.306452
# 13                 32.273209       7025.181818
# 14                 29.857701       6607.080214
# 15                 26.714946       6058.295699
# 16                 23.753782       5316.476684
# 17                 21.145357       4841.127551
# 18                 19.793125       4682.901042
# 19                 17.842604       4270.562500
# 20                 16.821231       4037.605128
# 21                 15.672335       3560.954315
#
#     Mortality - TB (exclude HIV)per Cap  Mortality - TB (exclude HIV)  \
# 0                             18.191095                   8140.766667
# 1                             18.380476                   8106.709524
# 2                             18.641801                   8052.265403
# 3                             18.341374                   7929.459716
# 4                             17.747109                   7646.848341
# 5                             17.304245                   7513.108491
# 6                             16.313066                   7271.410377
# 7                             16.053915                   7177.896226
# 8                             15.358679                   7011.141509
# 9                             14.835377                   6858.938679
# 10                            14.562958                   6676.807512
# 11                            14.384252                   6546.196262
# 12                            13.856495                   6392.387850
# 13                            13.633925                   6297.429907
# 14                            13.119299                   6256.514019
# 15                            13.050421                   6140.079439
# 16                            12.588551                   6066.911215
# 17                            12.339813                   5949.070093
# 18                            11.957710                   5764.471963
# 19                            11.369299                   5626.023364
# 20                            11.868224                   5881.163551
# 21                            12.429393                   6339.383178
#
#     Mortality - HIV & TB incident per Cap.  Mortality - HIV & TB  \
# 0                                17.309952           3244.404762
# 1                                17.031095           3151.714286
# 2                                15.921232           2951.492891
# 3                                15.770095           2930.582938
# 4                                15.590900           2867.649289
# 5                                16.085472           3060.292453
# 6                                16.269434           3126.665094
# 7                                15.784292           3049.632075
# 8                                15.269906           2901.358491
# 9                                14.077217           2800.226415
# 10                               11.670892           2670.460094
# 11                               11.093645           2265.000000
# 12                               10.914019           2113.219626
# 13                                9.843832           1950.420561
# 14                                8.934720           1758.467290
# 15                                7.964439           1589.098131
# 16                                7.096682           1400.915888
# 17                                6.313598           1254.186916
# 18                                5.638458           1111.672897
# 19                                4.949860            984.401869
# 20                                5.088318            936.481308
# 21                                4.867430            867.855140
#
#     Mortality - Per Cap     Mortality  Case Fatality Ratio  \
# 0             35.521381  11382.971429             0.000000
# 1             35.371810  11252.319048             0.000000
# 2             34.543128  10998.075829             0.000000
# 3             34.123886  10841.928910             0.000000
# 4             33.335498  10527.265403             0.000000
# 5             33.384481  10559.108491             0.000000
# 6             32.609764  10377.570755             0.000000
# 7             31.889481  10216.750000             0.000000
# 8             30.637311   9902.825472             0.000000
# 9             28.879009   9649.089623             0.000000
# 10            26.253803   9336.943662             0.000000
# 11            25.458551   8824.355140             0.000000
# 12            24.778738   8507.144860             0.000000
# 13            23.476355   8270.612150             0.000000
# 14            22.065374   8013.350467             0.000000
# 15            21.050888   7734.051402             0.000000
# 16            19.669393   7474.813084             0.000000
# 17            18.638505   7217.897196             0.000000
# 18            17.611355   6878.397196             0.000000
# 19            16.354019   6616.303738             0.000000
# 20            17.059953   6955.920561             0.000000
# 21            17.319206   7215.042056             0.154651
#
#     Case Fatality Ratio %  Total New and Relapse Cases  Mortality Rate  \
# 0                0.000000                    71.355051        0.152872
# 1                0.000000                    71.617085        0.150151
# 2                0.000000                    76.277767        0.147897
# 3                0.000000                    82.951471        0.143819
# 4                0.000000                    80.940597        0.137814
# 5                0.000000                    82.562950        0.135408
# 6                0.000000                    81.420098        0.131032
# 7                0.000000                    81.437005        0.129798
# 8                0.000000                    82.214000        0.127305
# 9                0.000000                    82.689853        0.124895
# 10               0.000000                    77.716651        0.123420
# 11               0.000000                    76.563380        0.122291
# 12               0.000000                    75.296364        0.120241
# 13               0.000000                    74.082098        0.119839
# 14               0.000000                    70.696493        0.120165
# 15               0.000000                    70.187990        0.119214
# 16               0.000000                    68.478357        0.119836
# 17               0.000000                    66.856840        0.119883
# 18               0.000000                    68.876557        0.117839
# 19               0.000000                    67.910048        0.116931
# 20               0.000000                    59.189710        0.125097
# 21              15.465116                    57.342919        0.129056
#
#     Mortality Rate - HIV
# 0               0.301715
# 1               0.312577
# 2               0.308383
# 3               0.319838
# 4               0.316822
# 5               0.340309
# 6               0.344790
# 7               0.350387
# 8               0.331400
# 9               0.333634
# 10              0.336296
# 11              0.296192
# 12              0.278300
# 13              0.277633
# 14              0.266149
# 15              0.262301
# 16              0.263505
# 17              0.259069
# 18              0.237390
# 19              0.230509
# 20              0.231940
# 21              0.243714

# %%
#Plot Cases per Capita by year with and without HI
cases, = plt.plot(by_year_df['Year'], by_year_df["Cases per Cap.(All)"], color="blue", label="Cases" )
hiv, = plt.plot(by_year_df['Year'], by_year_df['Cases -HIV & TB per Cap.'], color="red", label="Cases with HIV" )
plt.legend(handles=[cases, hiv], loc="best")
plt.title("Cases")
plt.xlabel("Year")
plt.ylabel("Per Capita")
plt.show()

# %%
#Plot mortality by year with and without HIV
mortality, = plt.plot(by_year_df['Year'], by_year_df["Mortality Rate"], color="blue", label="Without HIV" )
hiv_mortality, = plt.plot(by_year_df['Year'], by_year_df['Mortality Rate - HIV'], color="red", label="With HIV" )
plt.legend(handles=[hiv_mortality, mortality,], loc="best")
plt.title("Mortality")
plt.xlabel("Year")
plt.ylabel("Rate")
plt.show()

# %%
# High HDI Countries Cases and Mortality
high, = plt.plot(high_by_year_df['Year'], high_by_year_df['Cases -HIV & TB per Cap.'], color="red", label='Cases')
high_cases, = plt.plot(high_by_year_df['Year'], high_by_year_df['Mortality - HIV & TB incident per Cap.'], color="blue", label='Mortality')
plt.legend(handles=[high, high_cases], loc="best")
plt.title("High HDI Countries")
plt.xlabel("Year")
plt.ylabel("Per Capita")
plt.show()

# %%
# Low Countries
low, = plt.plot(low_by_year_df['Year'], low_by_year_df['Cases -HIV & TB per Cap.'], color="red", label='Cases')
low_cases, = plt.plot(low_by_year_df['Year'], low_by_year_df['Mortality - HIV & TB incident per Cap.'], color="blue", label='Mortality')
plt.legend(handles=[low, low_cases], loc="best")
plt.title("Low HDI Countries")
plt.xlabel("Year")
plt.ylabel("Per Capita")
plt.show()
