# %%
import warnings
warnings.filterwarnings('ignore')
from pathlib import Path
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
# Import CSV files 
TB_Rates = Path('Resources/TB_Rates.csv')
HDI = Path('Resources/HDI.csv')
Drug_Resistant_Rates = Path('Resources/Drug_Resistant_Rates.csv')

# Create Data Frames 
tb_rates_df = pd.read_csv(TB_Rates)
hdi_df = pd.read_csv(HDI)
drug_resistant_df = pd.read_csv(Drug_Resistant_Rates)

# %%
drug_resistant_df.head()
# Out:
#        country iso2 iso3  iso_numeric g_whoregion  year source_rr_new  \
# 0  Afghanistan   AF  AFG            4         EMR  2015         Model
# 1  Afghanistan   AF  AFG            4         EMR  2016         Model
# 2  Afghanistan   AF  AFG            4         EMR  2017         Model
# 3  Afghanistan   AF  AFG            4         EMR  2018         Model
# 4  Afghanistan   AF  AFG            4         EMR  2019         Model
#
#    e_rr_pct_new  e_rr_pct_new_lo  e_rr_pct_new_hi source_rr_ret  e_rr_pct_ret  \
# 0           5.1             0.45             19.0  Surveillance           8.6
# 1           5.1             0.50             20.0  Surveillance          11.0
# 2           5.2             0.53             19.0  Surveillance          15.0
# 3           5.2             0.54             20.0  Surveillance          19.0
# 4           5.3             0.55             20.0  Surveillance          24.0
#
#    e_rr_pct_ret_lo  e_rr_pct_ret_hi  e_inc_rr_num  e_inc_rr_num_lo  \
# 0              6.5             11.0          3600                0
# 1              9.4             14.0          3800                0
# 2             13.0             16.0          3900                0
# 3             17.0             20.0          4100                0
# 4             21.0             26.0          4300                0
#
#    e_inc_rr_num_hi
# 0            10000
# 1            11000
# 2            11000
# 3            12000
# 4            12000

# %%
#Remove Unused Columns
dr_drop =   ['iso2',
            'iso3','iso_numeric',
            'source_rr_new',
            'source_rr_ret']

drug_resistant_df.drop(dr_drop, inplace=True, axis=1)
drug_resistant_df
# Out:
#           country g_whoregion  year  e_rr_pct_new  e_rr_pct_new_lo  \
# 0     Afghanistan         EMR  2015           5.1             0.45
# 1     Afghanistan         EMR  2016           5.1             0.50
# 2     Afghanistan         EMR  2017           5.2             0.53
# 3     Afghanistan         EMR  2018           5.2             0.54
# 4     Afghanistan         EMR  2019           5.3             0.55
# ...           ...         ...   ...           ...              ...
# 1486     Zimbabwe         AFR  2017           3.5             3.20
# 1487     Zimbabwe         AFR  2018           2.9             2.70
# 1488     Zimbabwe         AFR  2019           2.4             2.20
# 1489     Zimbabwe         AFR  2020           2.0             1.70
# 1490     Zimbabwe         AFR  2021           1.7             1.30
#
#       e_rr_pct_new_hi  e_rr_pct_ret  e_rr_pct_ret_lo  e_rr_pct_ret_hi  \
# 0                19.0           8.6              6.5             11.0
# 1                20.0          11.0              9.4             14.0
# 2                19.0          15.0             13.0             16.0
# 3                20.0          19.0             17.0             20.0
# 4                20.0          24.0             21.0             26.0
# ...               ...           ...              ...              ...
# 1486              3.8          20.0             16.0             24.0
# 1487              3.1          21.0             18.0             25.0
# 1488              2.7          23.0             20.0             27.0
# 1489              2.4          25.0             20.0             30.0
# 1490              2.1          28.0             21.0             34.0
#
#       e_inc_rr_num  e_inc_rr_num_lo  e_inc_rr_num_hi
# 0             3600                0            10000
# 1             3800                0            11000
# 2             3900                0            11000
# 3             4100                0            12000
# 4             4300                0            12000
# ...            ...              ...              ...
# 1486          1500             1000             2000
# 1487          1200              850             1600
# 1488          1000              710             1400
# 1489           830              540             1100
# 1490           780              480             1100
#
# [1491 rows x 12 columns]

# %%
# Rename Columns
dr_rename = {
    'e_rr_pct_new': 'Est. New Cases %',
    'e_rr_pct_new_lo': 'Low Est. New Cases %',
    'e_rr_pct_new_hi': 'High Est. New Cases %',
    'e_rr_pct_ret':'Est. Reinfection %',
    'e_rr_pct_ret_lo':'Low Est. Reinfection %',
    'e_rr_pct_ret_hi':'High Est. Reinfection %',
    'e_inc_rr_num':'Estimated New Case Number',
    'e_inc_rr_num_lo':'Low Estimated New Case Number',
    'e_inc_rr_num_hi':'High Estimated New Case Number',
    'g_whoregion': 'Region'
}

drug_resistant_df.rename(columns=dr_rename, inplace=True)
drug_resistant_df
# Out:
#           country Region  year  Est. New Cases %  Low Est. New Cases %  \
# 0     Afghanistan    EMR  2015               5.1                  0.45
# 1     Afghanistan    EMR  2016               5.1                  0.50
# 2     Afghanistan    EMR  2017               5.2                  0.53
# 3     Afghanistan    EMR  2018               5.2                  0.54
# 4     Afghanistan    EMR  2019               5.3                  0.55
# ...           ...    ...   ...               ...                   ...
# 1486     Zimbabwe    AFR  2017               3.5                  3.20
# 1487     Zimbabwe    AFR  2018               2.9                  2.70
# 1488     Zimbabwe    AFR  2019               2.4                  2.20
# 1489     Zimbabwe    AFR  2020               2.0                  1.70
# 1490     Zimbabwe    AFR  2021               1.7                  1.30
#
#       High Est. New Cases %  Est. Reinfection %  Low Est. Reinfection %  \
# 0                      19.0                 8.6                     6.5
# 1                      20.0                11.0                     9.4
# 2                      19.0                15.0                    13.0
# 3                      20.0                19.0                    17.0
# 4                      20.0                24.0                    21.0
# ...                     ...                 ...                     ...
# 1486                    3.8                20.0                    16.0
# 1487                    3.1                21.0                    18.0
# 1488                    2.7                23.0                    20.0
# 1489                    2.4                25.0                    20.0
# 1490                    2.1                28.0                    21.0
#
#       High Est. Reinfection %  Estimated New Case Number  \
# 0                        11.0                       3600
# 1                        14.0                       3800
# 2                        16.0                       3900
# 3                        20.0                       4100
# 4                        26.0                       4300
# ...                       ...                        ...
# 1486                     24.0                       1500
# 1487                     25.0                       1200
# 1488                     27.0                       1000
# 1489                     30.0                        830
# 1490                     34.0                        780
#
#       Low Estimated New Case Number  High Estimated New Case Number
# 0                                 0                           10000
# 1                                 0                           11000
# 2                                 0                           11000
# 3                                 0                           12000
# 4                                 0                           12000
# ...                             ...                             ...
# 1486                           1000                            2000
# 1487                            850                            1600
# 1488                            710                            1400
# 1489                            540                            1100
# 1490                            480                            1100
#
# [1491 rows x 12 columns]

# %%
#find total cases and total reinfection cases; add values to dataframe
drug_resistant_df["Estimated Total Cases"]= drug_resistant_df["Estimated New Case Number"]/((drug_resistant_df["Est. New Cases %"]/100))
drug_resistant_df["Estimated Reinfection Cases"]=drug_resistant_df["Estimated Total Cases"]*((drug_resistant_df["Est. Reinfection %"]/100))
drug_resistant_df
# Out:
#           country Region  year  Est. New Cases %  Low Est. New Cases %  \
# 0     Afghanistan    EMR  2015               5.1                  0.45
# 1     Afghanistan    EMR  2016               5.1                  0.50
# 2     Afghanistan    EMR  2017               5.2                  0.53
# 3     Afghanistan    EMR  2018               5.2                  0.54
# 4     Afghanistan    EMR  2019               5.3                  0.55
# ...           ...    ...   ...               ...                   ...
# 1486     Zimbabwe    AFR  2017               3.5                  3.20
# 1487     Zimbabwe    AFR  2018               2.9                  2.70
# 1488     Zimbabwe    AFR  2019               2.4                  2.20
# 1489     Zimbabwe    AFR  2020               2.0                  1.70
# 1490     Zimbabwe    AFR  2021               1.7                  1.30
#
#       High Est. New Cases %  Est. Reinfection %  Low Est. Reinfection %  \
# 0                      19.0                 8.6                     6.5
# 1                      20.0                11.0                     9.4
# 2                      19.0                15.0                    13.0
# 3                      20.0                19.0                    17.0
# 4                      20.0                24.0                    21.0
# ...                     ...                 ...                     ...
# 1486                    3.8                20.0                    16.0
# 1487                    3.1                21.0                    18.0
# 1488                    2.7                23.0                    20.0
# 1489                    2.4                25.0                    20.0
# 1490                    2.1                28.0                    21.0
#
#       High Est. Reinfection %  Estimated New Case Number  \
# 0                        11.0                       3600
# 1                        14.0                       3800
# 2                        16.0                       3900
# 3                        20.0                       4100
# 4                        26.0                       4300
# ...                       ...                        ...
# 1486                     24.0                       1500
# 1487                     25.0                       1200
# 1488                     27.0                       1000
# 1489                     30.0                        830
# 1490                     34.0                        780
#
#       Low Estimated New Case Number  High Estimated New Case Number  \
# 0                                 0                           10000
# 1                                 0                           11000
# 2                                 0                           11000
# 3                                 0                           12000
# 4                                 0                           12000
# ...                             ...                             ...
# 1486                           1000                            2000
# 1487                            850                            1600
# 1488                            710                            1400
# 1489                            540                            1100
# 1490                            480                            1100
#
#       Estimated Total Cases  Estimated Reinfection Cases
# 0              70588.235294                  6070.588235
# 1              74509.803922                  8196.078431
# 2              75000.000000                 11250.000000
# 3              78846.153846                 14980.769231
# 4              81132.075472                 19471.698113
# ...                     ...                          ...
# 1486           42857.142857                  8571.428571
# 1487           41379.310345                  8689.655172
# 1488           41666.666667                  9583.333333
# 1489           41500.000000                 10375.000000
# 1490           45882.352941                 12847.058824
#
# [1491 rows x 14 columns]

# %%
# Out:
#       Est. New Cases %  Low Est. New Cases %  High Est. New Cases %  \
# year
# 2015            799.12                553.28                1353.08
#
#       Est. Reinfection %  Low Est. Reinfection %  High Est. Reinfection %  \
# year
# 2015              3807.5                 2193.14                   6974.6
#
#       Estimated New Case Number  Low Estimated New Case Number  \
# year
# 2015                     509365                         262005
#
#       High Estimated New Case Number  Estimated Total Cases  \
# year
# 2015                          767235           1.556136e+07
#
#       Estimated Reinfection Cases
# year
# 2015                 2.750259e+06

# %%
#create dataframe to show average regional new and reinfection rates by year
region_cases_df = drug_resistant_df.groupby(["Region", "year"]).mean()
region_cases_df
# Out:
#              Est. New Cases %  Low Est. New Cases %  High Est. New Cases %  \
# Region year
# AFR    2015          2.414043              1.202766               5.706383
#        2016          2.367021              1.198298               5.536170
#        2017          2.347660              1.194681               5.502128
#        2018           70964.463761                 11432.103014
#        2019           70300.669045                 11697.990067
#        2020           69914.964963                 11762.508856
#        2021           69889.563215                 12167.421876
# AMR    2015            8964.378783                  1161.954363
#        2016            9117.437657                  1137.786911
#        2017            9541.651136                  1158.168890
#        2018            9707.979616                  1145.802557
#        2019            9610.953526                  1133.385291
#        2020            9546.055906                  1104.202115
#        2021           10326.641643                  1210.653881
# EMR    2015           40442.336420                  6145.731035
#        2016           40791.328023                  5755.839892
#        2017           39946.692976                  5567.180695
#        2018           40129.810425                  5454.705459
#        2019           41252.831109                  5474.505397
#        2020           40543.098000                  5416.259019
#        2021           42827.652159                  5684.961669
# EUR    2015            8173.238718                  3687.646284
#        2016            7752.075980                  3430.862279
#        2017            7308.108318                  3182.347145
#        2018            6845.188326                  2916.275161
#        2019            6389.921333                  2680.649623
#        2020            5837.331711                  2519.632013
#        2021            5866.033758                  2477.221031
# SEA    2015          687023.253242                105229.042583
#        2016          686927.274841                104059.731777
#        2017          653898.649269                 99696.675522
#        2018          653066.030771                 98641.902654
#        2019          635328.516781                 91575.463151
#        2020          608864.115401                 88043.170770
#        2021          651917.541393                 95281.816878
# WPR    2015           76802.233405                 18015.134446
#        2016           75606.666990                 17766.558700
#        2017           78902.803868                 18004.048976
#        2018           78377.086742                 17592.546559
#        2019           76613.921868                 17006.019413
#        2020           76026.610128                 16922.737116
#        2021           81132.324820                 17714.134944

# %%
#plot for new cases by region
fig, ax = plt.subplots()

for year, new_df in region_cases_df.groupby(level = 0):
    ax.plot(new_df.index.get_level_values('year').values,
            new_df['Est. New Cases %'],
            label = new_df.index.get_level_values('Region').values[0],
            marker = 'o',
            linestyle = '-')

ax.legend(frameon = True, loc = 7)
plt.xlabel("Year")
plt.ylabel("New Case Rate (%)")
plt.title("Rifampicin Resistance New Cases Rate by Region")
plt.show()

# %%
#plot for reinfection cases by region

fig, ax = plt.subplots()

for year, new_df in region_cases_df.groupby(level = 0):
    ax.plot(new_df.index.get_level_values('year').values,
            new_df['Est. Reinfection %'],
            label = new_df.index.get_level_values('Region').values[0],
            marker = 'o',
            linestyle = '-')

ax.legend(frameon = True, loc = 9)
plt.xlabel("Year")
plt.ylabel("Reinfection Case Rate (%)")
plt.title("Rifampicin Resistance Reinfection Case Rate by Region")
plt.show()

# %%
#create variables to find global rates of new case aquisition and reinfection over time
reinfection_rates = drug_resistant_df.groupby(["year"]).mean()["Est. Reinfection %"]
new_case_rate = drug_resistant_df.groupby(["year"]).mean()["Est. New Cases %"]
# Out:
# year
# 2015    509365
# 2016    489057
# 2017    468412
# 2018    451928
# 2019    434993
# 2020    420071
# 2021    429738
# Name: Estimated New Case Number, dtype: int64

# %%
#plot new drug resistant cases and reinfection case rates over time
years = drug_resistant_df["year"].unique()
case_rate = plt.plot(years, new_case_rate, color="blue", label="New Case Rate", marker = "o")
reinfection = plt.plot(years, reinfection_rates, color="green", label="Reinfection Rate", marker = "o")
plt.legend()
plt.xlabel("Year")
plt.ylabel("Case Rate (%)")
plt.title("Rifampicin Resistance: New Cases vs. Reinfection")
plt.show()
